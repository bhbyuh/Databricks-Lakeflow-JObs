# %%
dbutils.widgets.text("file_name", "")

file_name=dbutils.widgets.get("file_name")
df = spark.read.format("parquet").load(f"/Volumes/dlt/default/raw_data/{file_name}.parquet")

# %%
df.write.format("delta").mode("overwrite").save(f"/Volumes/dlt/default/raw_data/sink/{file_name}")
