# %%
df=spark.createDataFrame([('a',1),('b',2),('c',3),('d',4),('e',5)])
df.show()
# Out:
# +---+---+
# | _1| _2|
# +---+---+
# |  a|  1|
# |  b|  2|
# |  c|  3|
# |  d|  4|
# |  e|  5|
# +---+---+

# %%
total_records=df.count()

# %%
total_records
# Out:
# 5

# %%
dbutils.jobs.taskValues.set("total_records", total_records)

# this will set key total_records in jobs taks and than we can featch this value on our whole job pipeline and we will featch it via parameters in jobs pipeline

# %%
# to use for sql query file job flow
order_id=1
dbutils.jobs.taskValues.set("order_id", order_id)
